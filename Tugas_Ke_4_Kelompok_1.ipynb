# %% [markdown]
# Tugas PSD ke 4
# Kelompok 1
#
# ---
#
#
# 1.   Hilal Gibran
# 2.   Mohammad rayhan akbar pratama
# 3.   Pandu prasetiyo aji
# 4.   Wahyu illahi rawi
# 5.   Nakamura silitonga
#
#
# Input
# ```
# # Import library yang diperlukan
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.linear_model import LinearRegression
#
# # Membuat data dummy untuk contoh linear regression
# np.random.seed(42)
# X = 2 * np.random.rand(100, 1)
# y = 4 + 3 * X + np.random.randn(100, 1)
#
# # Membuat instance dari Linear Regression model
# model = LinearRegression()
#
# # Melatih model menggunakan data
# model.fit(X, y)
#
# # Menampilkan parameter model
# print("Koefisien (slope):", model.coef_)
# print("Intercept:", model.intercept_)
#
# # Membuat prediksi menggunakan model yang telah dilatih
# X_new = np.array([[0], [2]])
# y_pred = model.predict(X_new)
#
# # Menampilkan hasil prediksi
# print("Prediksi untuk X_new:", y_pred)
#
# # Visualisasi data dan hasil regresi
# plt.scatter(X, y, color='blue', label='Data Asli')
# plt.plot(X_new, y_pred, color='red', linewidth=2, label='Linear Regression')
# plt.xlabel('X')
# plt.ylabel('y')
# plt.legend()
# plt.title('Contoh Linear Regression')
# plt.show()
# ```
#
#
#
# Output
# ![Screenshot 2023-12-05 193612.png](data:image/png;base64,...)
